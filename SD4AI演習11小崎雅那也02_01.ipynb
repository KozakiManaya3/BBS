# %% [markdown]
# <a href="https://colab.research.google.com/github/KozakiManaya3/BBS/blob/main/SD4AI%E6%BC%94%E7%BF%9211%E5%B0%8F%E5%B4%8E%E9%9B%85%E9%82%A3%E4%B9%9F02_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model = "gpt-4o-mini",
    messages = [
        {"role":"system","content":"You are a helpful assistant."},
        {"role":"user","content":"こんにちは!私はジョンと言います!"},
    ],
)

print(response.to_json(indent = 2))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipykernel_7056/2659544294.py in <cell line: 0>()
#       1 from openai import OpenAI
# ----> 2 client = OpenAI()
#       3 response = client.chat.completions.create(
#       4     model = "gpt-4o-mini",
#       5     messages = [
#
# /usr/local/lib/python3.12/dist-packages/openai/_client.py in __init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     192             and self.admin_api_key is None
#     193         ):
# --> 194             raise OpenAIError(
# ...
